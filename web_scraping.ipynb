# %%
print('hello')
# Out:
# hello

# %%
import requests

response = requests.get('https://books.toscrape.com/catalogue/a-light-in-the-attic_1000')

# print(response.status_code)

if response.status_code == 200:
    print('success')
else:
    print(f'Status Code: {response.status_code}')
# Out:
# success

# %%
import requests
from bs4 import BeautifulSoup

response = requests.get('https://quotes.toscrape.com')
soup = BeautifulSoup(response.text, "html.parser")


books = soup.find_all('div', class_="product_main")
print(books)

# for quote in quotes:
#     text = quote.find("span", class_="text").get_text()
#     author = quote.find("small", class_="author").get_text()
    
#     print(f'Quote: {text}\nAuthor: {author}')
#     print('---------------------------------------')
# Out:
# [<div class="quote" itemscope="" itemtype="http://schema.org/CreativeWork">
# <span class="text" itemprop="text">“The world as we have created it is a process of our thinking. It cannot be changed without changing our thinking.”</span>
# <span>by <small class="author" itemprop="author">Albert Einstein</small>
# <a href="/author/Albert-Einstein">(about)</a>
# </span>
# <div class="tags">
#             Tags:
#             <meta class="keywords" content="change,deep-thoughts,thinking,world" itemprop="keywords"/>
# <a class="tag" href="/tag/change/page/1/">change</a>
# <a class="tag" href="/tag/deep-thoughts/page/1/">deep-thoughts</a>
# <a class="tag" href="/tag/thinking/page/1/">thinking</a>
# <a class="tag" href="/tag/world/page/1/">world</a>
# </div>
# </div>, <div class="quote" itemscope="" itemtype="http://schema.org/CreativeWork">
# <span class="text" itemprop="text">“It is our choices, Harry, that show what we truly are, far more than our abilities.”</span>
# ...

# %%
import requests
from bs4 import BeautifulSoup
page = 1
while True:
    response = requests.get(f'https://quotes.toscrape.com/page{page}')
    soup = BeautifulSoup(response.text, "html.parser")

    # print (soup)


    quotes = soup.select(".quote")

    for quote in quotes:
        text = quote.select_one(".text").get_text()
        author = quote.select_one(".author").get_text()
        
        print(f'Quote: {text}\nAuthor: {author}')
        print('---------------------------------------')
# Out:
# Quote: “The world as we have created it is a process of our thinking. It cannot be changed without changing our thinking.”
# Author: Albert Einstein
# ---------------------------------------
# Quote: “It is our choices, Harry, that show what we truly are, far more than our abilities.”
# Author: J.K. Rowling
# ---------------------------------------
# Quote: “There are only two ways to live your life. One is as though nothing is a miracle. The other is as though everything is a miracle.”
# Author: Albert Einstein
# ---------------------------------------
# Quote: “The person, be it gentleman or lady, who has not pleasure in a good novel, must be intolerably stupid.”
# Author: Jane Austen
# ---------------------------------------
# Quote: “Imperfection is beauty, madness is genius and it's better to be absolutely ridiculous than absolutely boring.”
# Author: Marilyn Monroe
# ---------------------------------------
# ...

# %%
import requests
from bs4 import BeautifulSoup

page = 1

while True:
    response = requests.get(f'https://books.toscrape.com/catalogue/page-{page}.html')
    soup = BeautifulSoup(response.text, "html.parser")

    books = soup.find_all('article', class_="product_pod")

    if not books:
        break

    for book in books:
        title = book.h3.a.get('title')
        price = book.select_one(".price_color").get_text()
        stock = book.select_one(".instock").get_text(strip=True)
        
        print(f'Title: {title}\nPrice: {price}\nStock: {stock}')
        print('-------------------------')

    page += 1
# Out:
# Title: A Light in the Attic
# Price: Â£51.77
# Stock: In stock
# -------------------------
# Title: Tipping the Velvet
# Price: Â£53.74
# Stock: In stock
# -------------------------
# Title: Soumission
# Price: Â£50.10
# Stock: In stock
# -------------------------
# Title: Sharp Objects
# Price: Â£47.82
# Stock: In stock
# -------------------------
# Title: Sapiens: A Brief History of Humankind
# Price: Â£54.23
# Stock: In stock
# -------------------------
# Title: The Requiem Red
# Price: Â£22.65
# Stock: In stock
# -------------------------
# Title: The Dirty Little Secrets of Getting Your Dream Job
# Price: Â£33.34
# Stock: In stock
# -------------------------
# Title: The Coming Woman: A Novel Based on the Life of the Infamous Feminist, Victoria Woodhull
# Price: Â£17.93
# Stock: In stock
# -------------------------
# Title: The Boys in the Boat: Nine Americans and Their Epic Quest for Gold at the 1936 Berlin Olympics
# Price: Â£22.60
# Stock: In stock
# ...

# %%
import csv 
import requests 
from bs4 import BeautifulSoup

base_url = "https://books.toscrape.com/catalogue/page-{}.html"
csv_file = "books.csv"

with open(csv_file, mode='w', newline="", encoding="utf-8") as file:
    writer = csv.writer(file)
    writer.writerow(['Title','Price', 'Stock'])
    
    page = 1
    while True:
        url = base_url.format(page)
        response = requests.get(url)
        
        if response.status_code != 200:
            print(f'Failed to retrieve page: {page}. Status Code: {response.status_code}')
            break
        
        
        soup = BeautifulSoup(response.text, 'html.parser')
        books = soup.find_all('article', class_="product_pod")

        if not books:
            break

        for book in books:
            title = book.h3.a.get('title')
            price = book.select_one(".price_color").get_text()
            stock = book.select_one(".instock").get_text(strip=True)
            writer.writerow([title, price, stock])
        page += 1

print(f"All quotes saved to {csv_file}")
# Out:
# Failed to retrieve page: 51. Status Code: 404
# All quotes saved to books.csv

# %%
import requests
from bs4 import BeautifulSoup

response = requests.get('https://sandbox.oxylabs.io/products')    
soup = BeautifulSoup(response.text, "html.parser")


games = soup.find_all('div', class_="products-wrapper")
print(games)
# Out:
# [<div class="products-wrapper css-phdzty e1kord975"><style data-emotion="css e8at8d">.css-e8at8d{display:grid;position:relative;background-color:#ffffff;padding:1.5rem;border-radius:5px;}</style><div class="product-card css-e8at8d eag3qlw10"><style data-emotion="css 15g2oxy">.css-15g2oxy{margin-top:1rem;}</style><div class="css-15g2oxy eag3qlw3"></div><style data-emotion="css o171kl">.css-o171kl{-webkit-text-decoration:none;text-decoration:none;color:inherit;}</style><a class="card-header css-o171kl eag3qlw2" href="/products/1"><span style="box-sizing:border-box;display:block;overflow:hidden;width:initial;height:initial;background:none;opacity:1;border:0;margin:0;padding:0;position:relative"><span style="box-sizing:border-box;display:block;width:initial;height:initial;background:none;opacity:1;border:0;margin:0;padding:0;padding-top:100%"></span><img alt="The_Legend_of_Zelda:_Ocarina_of_Time" class="image" data-nimg="responsive" decoding="async" src="..." style="position:absolute;top
# ...

# %%
import requests
from bs4 import BeautifulSoup

response = requests.get('https://sandbox.oxylabs.io/products')    
soup = BeautifulSoup(response.text, "html.parser")


games = soup.find_all('div', class_="product-card")
# print(games)

for game in games:
    title = soup.select_one('.title').get_text()
    category = soup.select_one('.category').get_text()
    description = soup.select_one('.description').get_text()
    price = soup.select_one('.price-wrapper').get_text()
    stock = soup.select_one('.in-stock')
    
    print(f'Title: {title}\nCategory: {category}\nDescription: {description}\nPrice: {price}\nStock: {stock}')
    print('-------------------------')
# Out:
# Title: The Legend of Zelda: Ocarina of Time
# Category: Action Adventure Fantasy
# Description: As a young boy, Link is tricked by Ganondorf, the King of the Gerudo Thieves. The evil human uses Link to gain access to the Sacred Realm, where he places his tainted hands on Triforce and transforms the beautiful Hyrulean landscape into a barren wasteland. Link is determined to fix the problems he helped to create, so with the help of Rauru he travels through time gathering the powers of the Seven Sages.
# Price: 91,99 €
# Stock: None
# -------------------------
# Title: The Legend of Zelda: Ocarina of Time
# Category: Action Adventure Fantasy
# ...

# %%
import requests

response = requests.get('https://itch.io/games/new-and-popular/featured')
print(response.status_code)
# Out:
# 200

# %%
import requests
from bs4 import BeautifulSoup

page = 1

while True:
    response = requests.get(f'https://sandbox.oxylabs.io/products?page={page}')    
    soup = BeautifulSoup(response.text, "html.parser")


    games = soup.find_all('div', class_="products-wrapper")

    for game in games:
        title = soup.select_one('.title').get_text()
        category = soup.select_one('.category').get_text()
        description = soup.select_one('.description').get_text()
        price = soup.select_one('.price-wrapper').get_text()
        stock = soup.select_one('.in-stock')
        
        print(f'Title: {title}\nCategory: {category}\nDescription: {description}\nPrice: {price}\nStock: {stock}')
        print('--------------------------------------------------------------------------------------------------')
        
    page +=1
# Out:
# Title: The Legend of Zelda: Ocarina of Time
# Category: Action Adventure Fantasy
# Description: As a young boy, Link is tricked by Ganondorf, the King of the Gerudo Thieves. The evil human uses Link to gain access to the Sacred Realm, where he places his tainted hands on Triforce and transforms the beautiful Hyrulean landscape into a barren wasteland. Link is determined to fix the problems he helped to create, so with the help of Rauru he travels through time gathering the powers of the Seven Sages.
# Price: 91,99 €
# Stock: None
# --------------------------------------------------------------------------------------------------
# Title: Resident Evil Code: Veronica
# Category: Action Adventure Survival
# ...

# %%
import requests
from bs4 import BeautifulSoup

response = requests.get('https://itch.io/games/new-and-popular/featured')
soup = BeautifulSoup(response.text, "html.parser")

games = soup.select('.game_cell')
# print(games)

for game in games:
    title = game.select_one('.game_title').get_text()
    price = game.select_one('.price_tag').get_text()
    description = game.select_one('.game_text').get_text()
    creator = game.select_one('.game_author').get_text()
    genre = game.select_one('.game_genre').get_text()
    platform = game.select_one('.game_platform').get_text()
    
    print(f'Title: {title} -> {price}\nDesciption: {description}\nCreator: {creator}\nGenre: {genre}\nPlatform: {platform}')
    print('---------------')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[42], line 12
#      10 for game in games:
#      11     title = game.select_one('.game_title').get_text()
# ---> 12     price = game.select_one('.price_tag').get_text()
#      13     description = game.select_one('.game_text').get_text()
#      14     creator = game.select_one('.game_author').get_text()
#
# AttributeError: 'NoneType' object has no attribute 'get_text'
